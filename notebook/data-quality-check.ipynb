# %%
import duckdb as ddb
import pandas as pd

# %%
con = ddb.connect("../air_quality.db")

con

# %%
df = con.query("select * from raw.air_quality_data where parameter in ('pm25')").to_df()

df.head()
# Out:
#    location_id  sensors_id                                  location  \
# 0         8637       25072  US Diplomatic Post: Jakarta Central-8637
# 1         8637       25072  US Diplomatic Post: Jakarta Central-8637
# 2         8637       25072  US Diplomatic Post: Jakarta Central-8637
# 3         8637       25072  US Diplomatic Post: Jakarta Central-8637
# 4         8637       25072  US Diplomatic Post: Jakarta Central-8637
#
#              datetime       lat         lon parameter  units  value month  \
# 0 2023-12-31 18:00:00 -6.182536  106.834236      pm25  µg/m³ -999.0    01
# 1 2023-12-31 19:00:00 -6.182536  106.834236      pm25  µg/m³ -999.0    01
# 2 2023-12-31 20:00:00 -6.182536  106.834236      pm25  µg/m³ -999.0    01
# 3 2023-12-31 21:00:00 -6.182536  106.834236      pm25  µg/m³ -999.0    01
# 4 2023-12-31 22:00:00 -6.182536  106.834236      pm25  µg/m³ -999.0    01
#
#    year      ingestion_datetime
# 0  2024 2025-01-04 15:03:07.049
# 1  2024 2025-01-04 15:03:07.049
# 2  2024 2025-01-04 15:03:07.049
# 3  2024 2025-01-04 15:03:07.049
# 4  2024 2025-01-04 15:03:07.049

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   location_id         744 non-null    int64
#  1   sensors_id          744 non-null    int64
#  2   location            744 non-null    object
#  3   datetime            744 non-null    datetime64[us]
#  4   lat                 744 non-null    float64
#  5   lon                 744 non-null    float64
#  6   parameter           744 non-null    object
#  7   units               744 non-null    object
#  8   value               744 non-null    float64
#  9   month               744 non-null    object
#  10  year                744 non-null    int64
#  11  ingestion_datetime  744 non-null    datetime64[us]
# dtypes: datetime64[us](2), float64(3), int64(3), object(4)
# memory usage: 69.9+ KB

# %%
df.describe()
# Out:
#        location_id  sensors_id             datetime           lat  \
# count        744.0       744.0                  744  7.440000e+02
# mean        8637.0     25072.0  2024-01-16 05:30:00 -6.182536e+00
# min         8637.0     25072.0  2023-12-31 18:00:00 -6.182536e+00
# 25%         8637.0     25072.0  2024-01-08 11:45:00 -6.182536e+00
# 50%         8637.0     25072.0  2024-01-16 05:30:00 -6.182536e+00
# 75%         8637.0     25072.0  2024-01-23 23:15:00 -6.182536e+00
# max         8637.0     25072.0  2024-01-31 17:00:00 -6.182536e+00
# std            0.0         0.0                  NaN  8.887759e-16
#
#                 lon       value    year          ingestion_datetime
# count  7.440000e+02  744.000000   744.0                         744
# mean   1.068342e+02 -988.047043  2024.0  2025-01-04 15:03:07.049000
# min    1.068342e+02 -999.000000  2024.0  2025-01-04 15:03:07.049000
# 25%    1.068342e+02 -999.000000  2024.0  2025-01-04 15:03:07.049000
# 50%    1.068342e+02 -999.000000  2024.0  2025-01-04 15:03:07.049000
# 75%    1.068342e+02 -999.000000  2024.0  2025-01-04 15:03:07.049000
# max    1.068342e+02   87.000000  2024.0  2025-01-04 15:03:07.049000
# std    1.768036e-07  105.162806     0.0                         NaN

# %%
df.describe(include='O')
# Out:
#                                         location parameter  units month
# count                                        744       744    744   744
# unique                                         2         1      1     1
# top     US Diplomatic Post: Jakarta Central-8637      pm25  µg/m³    01
# freq                                         720       744    744   744

# %%
df[df.duplicated(subset=["location_id", "parameter", "units", "value", "datetime"])]
# Out:
# Empty DataFrame
# Columns: [location_id, sensors_id, location, datetime, lat, lon, parameter, units, value, month, year, ingestion_datetime]
# Index: []

# %%
df.groupby(by="parameter", as_index=False).count()
# Out:
#   parameter  location_id  sensors_id  location  datetime  lat  lon  units  \
# 0      pm25          744         744       744       744  744  744    744
#
#    value  month  year  ingestion_datetime
# 0    744    744   744                 744

# %%
con.close()
